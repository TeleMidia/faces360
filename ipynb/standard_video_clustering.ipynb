# %%
# %load_ext autotime
# Out:
# time: 0 ns (started: 2021-08-21 13:03:07 -03:00)

# %%
# %load_ext autoreload
import sys
sys.path.append('../')

import pandas as pd
import numpy as np
import cv2
import os
# Out:
# time: 766 ms (started: 2021-08-21 13:03:07 -03:00)

# %%
video_path = "D:/Movies/thegooddoctor.mp4"
dataframe_path = video_path.split('.')[0]+'_dataframe.pkl'
fps_extraction = 0.2
# Out:
# time: 0 ns (started: 2021-08-21 13:03:07 -03:00)

# %% [markdown]
# ### Clustering Video Faces Using Its Frames

# %%
from faces_clustering import VideoClustering
from faces_viewport import MTCNN_tf
# Out:
# Using TensorFlow backend.
# time: 7.59 s (started: 2021-08-21 13:03:07 -03:00)

# %%
#mtcnn_torch = MTCNN_Torch()
mtcnn_tf = MTCNN_tf()
# Out:
# time: 484 ms (started: 2021-08-21 13:03:15 -03:00)

# %%
video_clustering = VideoClustering('senet50', mtcnn_tf, 'agglomerative', verbose=5)
# Out:
# time: 8.28 s (started: 2021-08-21 13:03:16 -03:00)

# %%
res = video_clustering.cluster(video_path, fps=fps_extraction)
# Out:
# Processing D:/Movies/thegooddoctor.mp4
# extracting frames
# Original video fps is 24. Extracting at each 120.0 frames
# extracting embeddings
# HBox(children=(FloatProgress(value=0.0, max=42.0), HTML(value='')))
# clustering
# Best cluster number is 2
# time: 1min 9s (started: 2021-08-21 13:03:24 -03:00)

# %%
video_clustering.display_timeline(lines = True, limit = 22)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# time: 8.11 s (started: 2021-08-21 13:04:33 -03:00)
