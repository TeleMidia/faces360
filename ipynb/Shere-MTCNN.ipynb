# %%
import sys
sys.path.append('../')

# %%
from PIL import Image
from sphere_mtcnn import detect_faces_sphere, show_bboxes
from mtcnn_torch import detect_faces, show_bboxes

# %%
image = Image.open("C:/Users/paulo/Documents/videos360/vlog_gelo/frame_4272.jpg")
bounding_boxes, landmarks = detect_faces_sphere(image, min_face_size = 10, thresholds=[0.7, 0.3, 0.0])
show_bboxes(image, bounding_boxes)
# Out:
# ..\spherenet\sphere_cnn.py:50: RuntimeWarning: divide by zero encountered in true_divide
#   new_theta = theta + arctan(x*sin(v) / (rho*cos(phi)*cos(v) - y*sin(phi)*sin(v)))
# 71
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x1E6A4D31D90>

# %%
bounding_boxes, landmarks = detect_faces(image, min_face_size = 10, thresholds=[0.7, 0.3, 0.0])
show_bboxes(image, bounding_boxes)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x1E6A4D86D30>

# %%
image = Image.open("C:/Users/paulo/Documents/videos360/vlog_gelo/frame_7488.jpg")
bounding_boxes, landmarks = detect_faces_sphere(image, min_face_size = 10, thresholds=[0.7, 0.1, 0.0])
show_bboxes(image, bounding_boxes)

# %%
bounding_boxes, landmarks = detect_faces(image, min_face_size = 10, thresholds=[0.7, 0.07, 0.0])
show_bboxes(image, bounding_boxes)
