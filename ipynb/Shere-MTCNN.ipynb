# %%
import sys
sys.path.append('../')

# %%
from PIL import Image
from sphere_mtcnn import detect_faces_sphere
from mtcnn_torch import MTCNN_Torch, show_bboxes

# %%
image = Image.open("../data/dataset_360/FDDB-fold-01/2002_07_19_big_img_581.jpg")

# %%
bounding_boxes, landmarks = detect_faces_sphere(image, min_face_size = 30, thresholds=[0.9, 0.02, 0.02])
show_bboxes(image, bounding_boxes)
# Out:
# ..\spherenet\sphere_cnn.py:50: RuntimeWarning: divide by zero encountered in true_divide
#   new_theta = theta + arctan(x*sin(v) / (rho*cos(phi)*cos(v) - y*sin(phi)*sin(v)))
# 6
# <PIL.Image.Image image mode=RGB size=1280x640 at 0x14CEEABD970>

# %%
mtcnn = MTCNN_Torch(min_face_size = 10, thresholds=[0.7, 0.7, 0.7])

# %%
bounding_boxes, landmarks = mtcnn.detect_faces(image)
show_bboxes(image, bounding_boxes)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x640 at 0x2B44470C0D0>

# %%
bounding_boxes
# Out:
# array([[150.53827406, 437.1011349 , 186.72212589, 480.66690207,
#           0.99999988]])
